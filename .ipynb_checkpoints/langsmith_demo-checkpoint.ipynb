# %% [markdown]
# # LangSmith Demo
#
# **Project:** LLM Museum Description Generator

# %% [markdown]
# ## Agenda
# 1) Observability & Tracing: `@traceable`, LangGraph, metadata & filtering
# 2) Prompt Engineering: prompt playground, prompt hub, and canvas.
# 3) Testing & Evaluating: debugging, datasets, rule evaluators, LLM-as-judge, and annotation queues.
# 4) Monitoring & Improvements: online evals, automations, and dashboards.

# %%
# Load env
from dotenv import load_dotenv
load_dotenv()
import os
import warnings
warnings.filterwarnings("ignore") 
LANGSMITH_API_KEY = os.getenv("LANGSMITH_API_KEY")
LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")
LANGCHAIN_TRACING_v2 = os.getenv("LANGCHAIN_TRACING_v2")
PROJECT = os.getenv("LANGCHAIN_PROJECT")
print("Project: ", PROJECT)
# Out:
# Project:  langsmith-demo-0

# %% [markdown]
# ## 1) Observability & tracing: Simple Museum Label LLM Application

# %% [markdown]
# ![Simple LLM App](images/museum-app.jpg)

# %% [markdown]
# ### Using the @traceable decorator, metadata, run types:

# %%
"""
Fetch context from Wikipedia, then prompt an LLM to write a museum label.
Traced with LangSmith. Uses LangChain's `Document` type end-to-end.
"""

from typing import List, Tuple
import nest_asyncio
from langsmith import traceable
from openai import OpenAI

# LangChain bits
from langchain.docstore.document import Document
from langchain_community.document_loaders import WikipediaLoader



# ---- config ----
DEFAULT_MODEL = "gpt-4o-mini"
DEFAULT_TEMPERATURE = 0.2
WIKI_LANG = "en"
WIKI_MAX_DOCS = 2  # pull 1–2 short articles/snippets

MUSEUM_SYSTEM_PROMPT = """You are a museum label writer.
Write a concise (150–200 words), public-facing label for the given artwork using only the provided context.
Be concise, scholarly, and elegant; avoid jargon or define it briefly.
If context is insufficient, say so briefly."""


# ---- init ----
nest_asyncio.apply()
openai_client = OpenAI()

# -------------------------------------------------
# 1) Retrieve context from Wikipedia
# -------------------------------------------------
@traceable(run_type="retriever", metadata={"source": "wikipedia"})
def retrieve_wikipedia(
    artwork_name: str,
    lang: str = WIKI_LANG,
    max_docs: int = WIKI_MAX_DOCS
) -> List[Document]:
    """Fetch short context snippets from Wikipedia for an artwork."""
    loader = WikipediaLoader(query=artwork_name, lang=lang, load_max_docs=max_docs)
    docs = loader.load()
    for d in docs:
        title = d.metadata.get("title") or d.metadata.get("source") or artwork_name
        d.metadata["title"] = title
        d.metadata["source"] = f"Wikipedia:{title}"
    return docs

# -------------------------------------------------
# 2) Compose prompt messages
# -------------------------------------------------
@traceable(run_type="chain", metadata={"stage": "prompt_build"})
def build_messages(artwork_name: str, docs: List[Document]) -> List[dict]:
    """Builds the message list for the OpenAI chat API."""
    if not docs:
        user_content = (
            f"No reliable context found.\nArtwork: {artwork_name}\n"
            f"Write a brief public-facing label and note uncertainty."
        )
        return [
            {"role": "system", "content": MUSEUM_SYSTEM_PROMPT},
            {"role": "user", "content": user_content},
        ]

    context = "\n\n".join(d.page_content[:1500] for d in docs)
    user_content = (
        f"Artwork: {artwork_name}\n\n"
        f"Context (from Wikipedia):\n{context}\n\n"
        f"Write the label. If any details are uncertain, qualify them briefly."
    )
    return [
        {"role": "system", "content": MUSEUM_SYSTEM_PROMPT},
        {"role": "user", "content": user_content},
    ]

# -------------------------------------------------
# 3) Call OpenAI (LLM)
# -------------------------------------------------
@traceable(
    run_type="llm",
    metadata={
        "provider": "openai",
        "model": DEFAULT_MODEL,
        "temperature": DEFAULT_TEMPERATURE,
        "purpose": "museum_label_generation",
    },
)
def call_openai(
    messages: List[dict],
    model: str = DEFAULT_MODEL,
    temperature: float = DEFAULT_TEMPERATURE,
):
    """Executes the chat completion request to the OpenAI model."""
    return openai_client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )

# -------------------------------------------------
# 4) Orchestrator (Wikipedia ➜ LLM)
# -------------------------------------------------
@traceable(run_type="chain", metadata={"pipeline": "wikipedia_label", "version": "1.0"})
def museum_description_generator(artwork_name: str) -> Tuple[str, List[str]]:
    """Retrieves Wikipedia context and generates a museum label."""
    docs = retrieve_wikipedia(artwork_name)
    msgs = build_messages(artwork_name, docs)
    resp = call_openai(msgs)

    description = resp.choices[0].message.content
    return description

# ---- CLI ----
artwork = "The Birth of Venus"
description = museum_description_generator(artwork)

print("\n--- Museum Description ---\n")
print(description)
# Out:
# --- Museum Description ---
#
# **The Birth of Venus**
# **Alexandre Cabanel**
# **1863**
# **Oil on canvas**
# **Musée d'Orsay, Paris**
#
# In this captivating portrayal, Alexandre Cabanel reimagines the goddess Venus, embodying both classical beauty and modern sensuality. Shown at the Paris Salon of 1863, the painting quickly garnered acclaim and was acquired by Napoleon III for his personal collection. Venus, depicted with an ethereal palette, gazes at the viewer with a subtle ambiguity; her eyes, seemingly closed, suggest a state of both sleep and awareness, inviting contemplation.
#
# Cabanel's work stands out among the numerous female nudes of its time, merging mythological themes with a contemporary aesthetic that appealed to the elite. This duality—between the ancient and the modern—reflects the artist's skill in blending traditional iconography with the romantic ideals of the 19th century. The Birth of Venus exemplifies the era's fascination with beauty and desire, solidifying its place as a significant work in the canon of Western art.

# %% [markdown]
# ### Langgraph example: Out of the box tracing

# %%
import nest_asyncio
import operator
import os
from typing import List
from typing_extensions import TypedDict, Annotated

from langchain_core.messages import HumanMessage, AnyMessage, get_buffer_string
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
from IPython.display import Image, display

# LangChain docs + retriever
from langchain.docstore.document import Document
from langchain_community.retrievers import WikipediaRetriever  # emits retriever runs

nest_asyncio.apply()

# --- sanity print like the example ---
print("Tracing V2:", os.getenv("LANGCHAIN_TRACING_v2"))
print("Project:", os.getenv("LANGCHAIN_PROJECT"))
print("Key set:", bool(os.getenv("LANGCHAIN_API_KEY")))

# ---- config ----
DEFAULT_MODEL = "gpt-4o-mini"
DEFAULT_TEMPERATURE = 0.2
WIKI_MAX_DOCS = 2
retriever = WikipediaRetriever(top_k_results=WIKI_MAX_DOCS)
llm = ChatOpenAI(model=DEFAULT_MODEL, temperature=DEFAULT_TEMPERATURE)

# Prompt text 
MUSEUM_PROMPT = """You are a museum label writer.

Write a concise (150–200 words), public-facing label for the given artwork using only the provided context.
Be concise, scholarly, and elegant; avoid jargon or define it briefly. If context is insufficient, say so briefly.

Artwork: {question}

Context (from Wikipedia):
{context}

Write the label. If any details are uncertain, qualify them briefly.
"""

# -------- Graph state (match the clean example's shape) --------
class GraphState(TypedDict):
    question: str
    messages: Annotated[List[AnyMessage], operator.add]
    documents: List[Document]

# -------- Nodes --------
def retrieve_documents(state: GraphState):
    messages = state.get("messages", [])
    question = state["question"]
    # Use conversation buffer + query (mirrors the example)
    query = f"{get_buffer_string(messages)} {question}".strip()
    documents = retriever.invoke(query)  # <- LangChain retriever => shows 'retriever' run
    return {"documents": documents}

def generate_response(state: GraphState):
    question = state["question"]
    messages = state.get("messages", [])
    documents = state.get("documents", [])

    context = "\n\n".join(doc.page_content for doc in documents) if documents else \
              f"No reliable context found for '{question}'."

    prompt_text = MUSEUM_PROMPT.format(context=context, question=question)
    generation = llm.invoke([HumanMessage(content=prompt_text)])  # <- shows 'llm' run
    return {"documents": documents, "messages": [HumanMessage(question), generation]}

# -------- Build the graph --------
graph_builder = StateGraph(GraphState)
graph_builder.add_node("retrieve_documents", retrieve_documents)
graph_builder.add_node("generate_response", generate_response)

graph_builder.add_edge(START, "retrieve_documents")
graph_builder.add_edge("retrieve_documents", "generate_response")
graph_builder.add_edge("generate_response", END)

museum_graph = graph_builder.compile()

try:
    display(Image(museum_graph.get_graph().draw_mermaid_png()))
except Exception:
    pass

# -------- Simple CLI --------
if __name__ == "__main__":
    out = museum_graph.invoke({"question": "The Birth of Venus", "messages": []})
    msgs = out.get("messages", [])
    label = msgs[-1].content if msgs else ""
    print("\n--- Museum Description ---\n")
    print(label)
# Out:
# Tracing V2: true
# Project: langsmith-demo-0
# Key set: True
# --- Museum Description ---
#
# **The Birth of Venus**
# Sandro Botticelli
# c. 1484–1486
# Tempera on canvas
#
# In this iconic painting, Sandro Botticelli captures the moment of Venus's arrival on the shore, emerging from the sea in a giant scallop shell. The goddess, depicted in a state of graceful nudity, is propelled by the wind gods Zephyrus and Aura, who blow her towards the land, symbolizing beauty and love. To the right, a figure representing one of the Horae, or goddesses of the seasons, awaits to drape Venus in a rich cloak, embodying the themes of renewal and fertility.
#
# Botticelli's work stands as a hallmark of the Italian Renaissance, celebrated for its lyrical beauty and mythological depth. The painting's composition and scale were unprecedented in Western art since antiquity, showcasing the artist's mastery in rendering the human form and evoking emotion. While its title, "The Birth of Venus," was assigned later, the scene illustrates a pivotal moment in the goddess's narrative, emphasizing her allure and significance in classical mythology. Today, it remains a defining image of Renaissance art, housed in the Uffizi Gallery, Florence.

# %% [markdown]
# ### Additional Tracing Resources:
#
# - [OpenAI wrapper: wrap_openai](https://docs.smith.langchain.com/reference/python/wrappers/langsmith.wrappers._openai.wrap_openai)
# - [Conversational tracing](https://docs.smith.langchain.com/reference/python/wrappers/langsmith.wrappers._openai.wrap_openai)
# - [Trace context manager](https://docs.smith.langchain.com/reference/python/run_helpers/langsmith.run_helpers.trace)
# - [LangGraph Studio](https://langchain-ai.github.io/langgraphjs/concepts/langgraph_studio/)

# %% [markdown]
# ## 2) Prompt Engineering: prompt hub, templates, and canvas

# %% [markdown]
# ### Pulling prompt template from prompthub

# %%
from typing import List, Tuple
from langsmith import Client, traceable
from langchain.docstore.document import Document
from langchain_community.document_loaders import WikipediaLoader

client = Client()  
PROMPT = client.pull_prompt("target-audience-prompt:b07b0a6b", include_model=True)

ARTWORK = "Mona Lisa"
AUDIENCE = "general public"

def museum_caption_generator(artwork: str, audience: str, prompt):
    @traceable(run_type="llm", name="generate_label", metadata={
        "provider": "openai",
        "model": DEFAULT_MODEL,
        "temperature": DEFAULT_TEMPERATURE,
        "purpose": "museum_label_generation",
    },)
    def generate_label(artwork: str, docs: List[Document], audience: str = "general public") -> str:
        context = "\n\n".join(d.page_content[:1500] for d in docs) if docs else ""
        result = prompt.invoke({"artwork": artwork, "context": context, "audience": audience})
        return getattr(result, "content", str(result))

    @traceable(run_type="retriever", name="retrieve_wikipedia")
    def retrieve_wikipedia(artwork: str, lang: str = "en", max_docs: int = 2) -> List[Document]:
        docs = WikipediaLoader(query=artwork, lang=lang, load_max_docs=max_docs).load()
        for d in docs:
            t = d.metadata.get("title") or d.metadata.get("source") or artwork
            d.metadata["title"] = t
            d.metadata["source"] = f"Wikipedia:{t}"
        return docs

    @traceable(run_type="chain", name="museum_label_from_wikipedia")
    def museum_label_from_wikipedia(artwork: str, audience: str = "general public") -> Tuple[str, List[str]]:
        docs = retrieve_wikipedia(artwork)
        label = generate_label(artwork, docs, audience)
        cites = [d.metadata.get("source", "Wikipedia") for d in docs] if docs else []
        return label

    return museum_label_from_wikipedia(artwork, audience)

print(museum_caption_generator(ARTWORK, AUDIENCE, PROMPT))
# Out:
# Mona Lisa
# Leonardo da Vinci
#
# This half-length portrait by Leonardo da Vinci is widely regarded as an archetypal masterpiece of the Italian Renaissance. Painted in oil on a white poplar panel, it is traditionally considered to depict the Italian noblewoman Lisa del Giocondo, though Leonardo never delivered the work to her family and the identification remains conventional rather than certain. Scholars date the painting to about 1503–1506, with Leonardo possibly revising it as late as 1517.
#
# The painting’s enduring power lies in its novel qualities: the sitter’s enigmatic expression; a monumental, quietly composed arrangement; the subtle modelling of forms; and “atmospheric illusionism” — a soft rendering that creates the illusion of depth and air. After Leonardo’s death the work entered the French royal collection (acquired by King Francis I) and, now the property of the French Republic, has been on display at the Louvre since 1797.
#
# The Mona Lisa’s modern fame was amplified by its 1911 theft by Vincenzo Peruggia, who claimed patriotic motives; its recovery in 1914 sparked unprecedented publicity and many cultural responses, helping to make it arguably the best-known painting in the world.

# %% [markdown]
# ## 3) Testing & Evaluating: datasets, rule evaluators, LLM-as-judge, and annotation queues

# %% [markdown]
# ![Evaluation Lifecycle](images/evaluation_lifecycle.png)

# %% [markdown]
# ### Loading a dataset

# %%
GOLDEN_EXAMPLES = [
    
    (
        "The Starry Night",
        "general public",
        """Vincent van Gogh painted The Starry Night in 1889 while staying at an asylum in Saint-Rémy, in southern France.
Thick, swirling strokes of blue, yellow, and white turn the night sky into a living current that seems to pulse above a quiet village.
The cypress at left rises like a dark flame, linking earth and sky. Van Gogh did not record the view exactly as he saw it; the village is imagined, and the bold rhythms
of paint carry his emotional response to nature more than a literal description. The work reflects van Gogh’s intense study of color and his belief that brushwork could express
inner feeling—an idea that helped shape modern art. Although the picture suggests turbulence, it is carefully structured: sweeping arcs lead the eye across the canvas, and constellations
anchor the composition. This painting invites us to feel the night not as empty darkness but as a vibrant, moving space filled with light and energy."""
    ),
    (
        "Mona Lisa",
        "general public",
        """Leonardo da Vinci’s Mona Lisa (about 1503–6) is among the most studied portraits in Western art.
The sitter—likely Lisa Gherardini, a Florentine merchant’s wife—meets the viewer with a famously subtle smile.
Leonardo achieves this effect through sfumato, the delicate blending of tones that softens edges around the mouth and eyes,
making the expression appear to shift with our gaze. The atmospheric landscape behind her recedes through layers of blue, a demonstration of
Leonardo’s interest in optics and the behavior of light. The three-quarter pose, turned slightly toward us, was innovative for its time and has
become a standard in portraiture. Painted with extraordinary finesse on poplar, the panel rewards close looking: the sitter’s folded hands convey calm dignity,
and the carefully modeled face suggests an inner life rather than a status display. The picture’s fame owes not only to its history, but to the way it balances
observed detail with mystery, inviting endless interpretation."""
    ),
    (
        "The Birth of Venus",
        "general public",
        """Sandro Botticelli’s The Birth of Venus (late 1480s) imagines the goddess arriving at the shore, carried on a shell by the wind.
The scene draws on ancient poetry and the Renaissance revival of classical mythology. Venus’s modest pose recalls antique sculpture,
yet the painting’s graceful contours and flowing hair are distinctly Botticelli’s—more lyrical than naturalistic. Executed with tempera on canvas,
an unusual support for Florence at the time, the work may have adorned a domestic interior connected with the Medici circle.
Viewers in the fifteenth century could read the image on several levels: as a charming myth, as a celebration of beauty’s civilizing power,
and, in Neoplatonic terms, as a metaphor for divine love entering the world. The idealized shore and rhythmic lines create a harmonious, almost musical surface.
Rather than presenting a literal event, Botticelli offers a poetic vision, inviting us to reflect on how art transforms stories into enduring images."""
    ),
    (
        "Girl with a Pearl Earring",
        "general public",
        """Johannes Vermeer’s Girl with a Pearl Earring (about 1665) is not a formal portrait but a “tronie”—a study of an expressive figure in exotic dress.
The young woman turns toward us as if surprised, lips parted, eyes bright. Light falls gently across her face and glints on the oversized pearl,
a simple device that anchors the composition. Vermeer’s restrained palette—deep blues, warm ochers, and soft flesh tones—heightens the sense of intimacy.
We do not know the sitter’s identity, and the turban was not common Dutch attire; both choices invite curiosity rather than biography.
The smooth surface and subtle transitions of tone reveal Vermeer’s mastery of optical effects, perhaps informed by close looking through lenses.
Stripped of narrative detail, the painting focuses on a moment of encounter between viewer and subject. Its quiet power lies in how little it tells us:
the work suggests personality and presence without fixing them, leaving room for our imagination."""
    ),
    (
        "The Persistence of Memory",
        "general public",
        """In The Persistence of Memory (1931), Salvador Dalí gives the solidity of clocks a dreamlike instability.
Pocket watches soften and slump across a barren landscape, their hands still marking time even as the metal seems to melt.
A pale, sleeping head at center—often read as a self-referential form—adds to the uncanny mood. Dalí, a leading Surrealist,
used meticulously realistic technique to render irrational scenes, capturing the logic of dreams where familiar objects behave in unfamiliar ways.
The ants and fly suggest decay and the irritation of time’s passage. The rocky background refers to the coast of Catalonia, grounding fantasy in a real place.
Rather than proposing a single meaning, the painting prompts us to consider how memory stretches and compresses experience.
By making time itself appear fluid, Dalí transforms an everyday instrument into a symbol of the mind’s elastic, subjective world."""
    ),
    (
        "Guernica",
        "general public",
        """Pablo Picasso painted Guernica in 1937 in response to the bombing of the Basque town during the Spanish Civil War.
The vast canvas, rendered in blacks, whites, and grays, rejects color to emphasize the starkness of the tragedy.
Fragmented figures—a screaming mother with her dead child, a gored horse, a fallen warrior—convey grief and chaos without literal storytelling.
Picasso drew on both modern Cubist fracture and classical motifs, such as the bull, to create a universal image of civilian suffering.
The electric light overhead reads as both a bulb and an unblinking eye, amplifying the sense of exposure.
Guernica is not a battlefield scene; it is a cry against the violence that reaches into homes and streets.
Its enduring power comes from the tension between distance and immediacy: the abstracted forms resist sensational detail, yet the emotion is unmistakable."""
    ),
    (
        "The Night Watch",
        "general public",
        """Rembrandt’s so-called Night Watch (1642) actually depicts a daytime departure of a civic militia company led by Captain Frans Banning Cocq.
The popular title arose later when darkened varnish made the scene seem nocturnal. Rembrandt animates what could have been a static group portrait:
figures stride, turn, and interact as light cuts across the crowd, spotlighting the captain in black and his lieutenant in yellow.
The little girl with a chicken—perhaps a symbol of the company—adds a flash of mystery and movement. Rembrandt’s mastery of chiaroscuro
creates depth and drama, while the diagonals of spears and banners guide the eye. Painted at a monumental scale,
the work celebrates civic pride as much as individual likeness. It invites viewers to experience the energy of Amsterdam’s guardsmen
at the height of the Dutch Golden Age."""
    ),
    (
        "The Last Supper",
        "general public",
        """Leonardo da Vinci’s Last Supper (about 1495–98) captures the moment Christ tells the apostles that one of them will betray him.
Seated along one side of a long table, the figures react in groups of three, their gestures and expressions revealing shock, doubt, and inquiry.
Leonardo used linear perspective to draw the architecture toward a vanishing point behind Christ’s head, clarifying his central role.
Painted on the refectory wall of Santa Maria delle Grazie in Milan, the work combines experimental technique with careful observation,
which sadly contributed to its early deterioration. Despite losses and restorations, the composition remains compelling:
it is less a narrative snapshot than a study of human response. The quiet triangle of Christ’s body contrasts with the rising motion around him,
inviting contemplation of betrayal and forgiveness."""
    ),
    (
        "American Gothic",
        "general public",
        """Grant Wood’s American Gothic (1930) shows a stern farmer and a young woman before a small house with a pointed, “Gothic” window.
Painted during the Great Depression, the image is both affectionate and ambiguous: the crisply rendered details—the pitchfork, the bib overalls,
the cameo brooch—suggest pride in rural labor, yet the tight composition and solemn faces invite questions about hardship and restraint.
Wood drew inspiration from Northern Renaissance clarity and from the actual Carpenter Gothic house in Eldon, Iowa.
The painting quickly became a cultural touchstone, borrowed for satire and celebration alike. Its power lies in how it balances
specificity and symbol: the figures are individuals, yet they also stand for a broader American idea of steadiness in difficult times."""
    ),
    (
        "The Scream",
        "general public",
        """Edvard Munch’s The Scream (first version 1893) transforms a personal sense of anxiety into a universal image.
A figure on a bridge presses hands to its face as the sky ripples in bands of red, orange, and blue.
Munch described experiencing “a great, infinite scream through nature,” and he translated that sensation into undulating lines and bold color.
Several versions exist—paintings, pastels, prints—each exploring the theme. The landscape likely overlooks Oslofjord, but the scene is more emotional than geographic.
Perspective tilts, and the railing thrusts diagonally across the picture, intensifying the figure’s isolation.
Rather than depict a specific event, Munch gives form to a feeling that many viewers recognize, making the painting a landmark of Expressionism."""
    ),
    (
        "The School of Athens",
        "general public",
        """Raphael’s School of Athens (1510–11), painted in the papal apartments in Rome, presents an ideal gathering of ancient philosophers and scientists.
At the center stand Plato and Aristotle, framed by grand classical architecture that echoes their intellectual stature.
Around them, recognizable portraits—Leonardo as Plato, perhaps Michelangelo as Heraclitus—merge Renaissance contemporaries with antiquity.
The fresco balances clarity and variety: sweeping arches organize a complex assembly, while gestures and poses suggest lively debate.
Rather than depicting a single historical moment, Raphael visualizes the pursuit of knowledge as a shared, cumulative endeavor.
The work celebrates human reason and the harmony of thought, themes central to the Renaissance self-image."""
    ),
    (
        "Water Lilies",
        "general public",
        """Claude Monet’s Water Lilies series occupied the artist for decades, culminating in expansive panels intended to surround the viewer.
Painted in his garden at Giverny, the works dissolve horizon and shoreline: water, reflections, and plants become a continuous field of color.
Monet tracked subtle changes of light and weather, layering touches of paint that hover between observation and abstraction.
These late canvases are less about botanical detail than about perception itself—how the eye experiences shimmering surfaces over time.
Standing close, the brushstrokes read as independent marks; step back, and they cohere into floating pads and mirrored skies.
The series invites slow looking and rewards it, turning a garden pond into a meditation on seeing."""
    ),
    (
        "The Kiss",
        "general public",
        """Gustav Klimt’s The Kiss (1907–08) embodies the decorative richness of the Vienna Secession.
Two figures kneel at the edge of a flowery meadow, wrapped in a golden cloak patterned with rectangles and circles that distinguish masculine and feminine forms.
Klimt applied gold leaf over oil paint, recalling Byzantine mosaics while asserting modern design.
The faces and hands are softly modeled, but the garments flatten into ornate surface, compressing depth and creating an intimate, iconic image.
Rather than narrate a story, the painting offers a timeless moment of embrace, balancing sensuality and tenderness.
Its appeal lies in the union of precious materials, patterned geometry, and human feeling."""
    ),
    (
        "Liberty Leading the People",
        "general public",
        """Eugène Delacroix painted Liberty Leading the People (1830) after the July Revolution in Paris.
The allegorical figure of Liberty strides over barricades, holding the tricolor flag and a musket, while citizens from different walks of life rally behind her.
Smoke and rubble set the scene of urban conflict; warm, broken brushwork conveys urgency and movement.
The painting blends reportage with symbolism: Liberty is an idea made visible, at once a real participant and a timeless emblem.
Delacroix does not offer a tidy victory picture; fallen bodies in the foreground remind us of the cost of political change.
The work became an enduring image of struggle and civic hope."""
    ),
    (
        "The Great Wave off Kanagawa",
        "general public",
        """Katsushika Hokusai’s The Great Wave off Kanagawa (about 1831) is a woodblock print from the series Thirty-Six Views of Mount Fuji.
A towering wave curls into sharp claws, about to crash over fishing boats, while the distant mountain remains calm and triangular.
Hokusai used imported Prussian blue to achieve intense, layered color, and he combined traditional ukiyo-e techniques with a fresh sense of space.
The print captures both the drama of the sea and the endurance of those who work on it. Its bold design and asymmetrical composition
influenced many European artists in the late nineteenth century, contributing to the Japonisme movement. The image remains a global icon of nature’s power."""
    ),
    (
        "Las Meninas",
        "general public",
        """Diego Velázquez’s Las Meninas (1656) is a court scene that complicates who is looking at whom.
The painter includes himself at left, brush in hand, while the young Infanta Margarita stands among her attendants.
A mirror at the back reflects the king and queen, suggesting they stand where we do, outside the picture.
The composition plays with space, status, and the act of painting itself: is this a portrait, a studio view, or both?
Velázquez’s loose, luminous brushwork brings life to textures of fabric and hair, while the restrained palette keeps attention on light and presence.
The painting invites us into a moment that feels spontaneous yet carefully arranged, making viewers collaborators in the scene."""
    ),
    (
        "Arrangement in Grey and Black No. 1 (Whistler’s Mother)",
        "general public",
        """James McNeill Whistler’s Arrangement in Grey and Black No. 1 (1871), popularly known as Whistler’s Mother,
is both a portrait of the artist’s mother and a study in tonal harmony. The sitter’s profile and dark dress create a strong silhouette against
a pale wall punctuated by a framed print and curtain. Whistler emphasized compositional balance over anecdote,
insisting on the painting’s musical title to highlight structure and mood rather than story.
The result is dignified and austere, yet intimate. The work became an emblem of maternal fortitude,
even though Whistler intended it as an exploration of visual arrangement. Its quiet authority rewards slow attention."""
    ),
    (
        "The Hay Wain",
        "general public",
        """John Constable’s The Hay Wain (1821) shows a rural wagon crossing the River Stour on a summer day.
Constable, who knew this countryside intimately, painted from sketches made outdoors to capture shifting weather and light.
The scene is not nostalgic fantasy but a carefully observed working landscape—cottage, trees, water, and sky held in balance.
Broken touches of paint animate foliage and reflections, while the low horizon grants the sky unusual prominence.
Exhibited in Paris, the picture won praise from French critics and influenced the development of landscape painting there.
Its enduring appeal lies in the sense that nature and human labor coexist without drama, a harmony both real and idealized."""
    ),
    (
        "Olympia",
        "general public",
        """Édouard Manet’s Olympia (1863) shocked Paris when first exhibited.
The nude woman meets the viewer’s gaze directly, her tense pose and outlined form rejecting the soft idealization of earlier Venus figures.
A maid presents flowers—likely from a client—while a black cat arches at the bed’s edge, replacing the customary lapdog of fidelity.
Manet modernized the classical theme by placing it in contemporary Paris, making the subject’s social reality impossible to ignore.
The painting questioned conventions of beauty, propriety, and looking itself. Today it is recognized as a pivotal work that opened the door
to modern treatments of the figure and the complexities of representation."""
    ),
    (
        "A Sunday Afternoon on the Island of La Grande Jatte",
        "general public",
        """Georges Seurat’s La Grande Jatte (1884–86) depicts Parisians at leisure along the Seine, constructed with thousands of small dots of color.
This technique—often called pointillism—relies on optical mixture: from a distance, the eye blends neighboring hues into vibrant tones.
Figures appear still, almost sculptural, yet the scene is carefully composed with repeating shapes and measured intervals.
Seurat’s method was grounded in contemporary color theory, giving the painting a scientific air even as it portrays everyday life.
The work invites viewers to step forward to study the brushwork and step back to see the forms resolve, turning looking itself into part of the experience."""
    ),
        (
        "Impression, Sunrise",
        "general public",
        """Claude Monet painted Impression, Sunrise in 1872, looking across the harbor of Le Havre at dawn.
Loose, visible strokes sketch boats, masts, and chimneys as the sun’s orange disk lifts through bluish mist.
Rather than detailing every form, Monet records the fleeting effect of light on water—ripples catch color and dissolve again.
When shown in 1874, a critic mocked the title as merely an “impression,” unintentionally naming the Impressionist movement.
The small canvas demonstrates how the group favored direct observation, open brushwork, and high-key color over academic finish.
Monet’s palette is limited but strategic: complementary blues and oranges create vibration, while grays hold the scene together.
What matters is the sensation of a moment—cool air, muffled silhouettes, a spark of warmth—more than a topographical view.
The picture invites us to experience sunrise as an event of looking, when forms are still emerging and the eye does the work of completion."""
    ),
    (
        "Bal du moulin de la Galette",
        "general public",
        """Pierre-Auguste Renoir’s Bal du moulin de la Galette (1876) captures a Sunday dance in Montmartre, a working-class district of Paris.
Dappled sunlight filters through trees, breaking figures into patches of blue, rose, and gold; the flicker suggests movement and chatter.
Renoir composes a crowded yet airy space, alternating groups and diagonals so the gaze circulates like the dancers.
Faces and fabrics are indicated with swift, creamy touches rather than tight lines, a hallmark of Impressionist practice.
The painting celebrates modern leisure—friends meeting, music playing—without idealizing wealth or power.
At the same time, it is a study of perception: how outdoor light unsettles contours and turns shadows colorful.
Renoir’s affection for human sociability governs the scene; pleasure itself becomes the subject.
The canvas invites viewers to feel momentary participation—sun on skin, a turn of the waltz—held in paint before it slips away."""
    ),
    (
        "The Dance Class",
        "general public",
        """Edgar Degas’s The Dance Class (1874) shows a rehearsal room rather than a staged performance.
The viewer looks slightly from above, as if standing in the studio with the teacher and students.
Off-center cropping, tilted floorboards, and figures cut by the frame reflect Degas’s interest in photography and Japanese prints.
While satin ribbons and tutus attract the eye, the picture is about labor: stretching, waiting, repeating steps.
Pastel and oil combine to make surfaces that are soft yet precise, capturing the flare of a skirt and the weight of a stance.
Degas’s art often examined modern Paris from the wings—café tables, theaters, racecourses—places where people prepare or pass time.
Here, discipline and aspiration meet in an unglamorous space, reminding us that grace is practiced, not simply given.
The scene feels observed rather than posed, inviting us to notice small dramas at the edges while the lesson proceeds."""
    ),
    (
        "The Cradle",
        "general public",
        """Berthe Morisot’s The Cradle (1872) presents a quiet scene of motherhood.
A woman watches over a sleeping infant behind a gauzy veil, her profile composed and tender.
Morisot’s light, rapid strokes keep forms open, allowing the white of the canvas to shimmer through flesh and fabric.
Rather than a grand narrative, the picture offers an intimate moment marked by care and attention.
Morisot exhibited with the Impressionists from the start, helping define the group’s concern with modern domestic life as a worthy subject.
Here, delicate color harmonies—pale rose, blue, and gray—create a breathing atmosphere.
The veil, both barrier and protection, becomes a metaphor for the thin line between public display and private feeling.
The painting honors the work of tending and watching, and shows how Impressionist technique could serve subtle human themes."""
    ),
    (
        "The Child’s Bath",
        "general public",
        """Mary Cassatt’s The Child’s Bath (1893) portrays a caregiver bathing a young girl, a scene of everyday tenderness.
Flattened patterns and cropped viewpoints reveal Cassatt’s study of Japanese prints, which were widely collected in Paris at the time.
Muted violets and greens set off the warm tones of skin; stripes and floral motifs establish rhythm without excess detail.
Cassatt emphasizes touch and attention—the gentle support of the adult’s hand, the child’s focused gaze on her own foot.
The painting dignifies domestic care as a modern subject, neither sentimental nor clinical.
As with many Impressionists, Cassatt is less concerned with a fixed outline than with the experience of looking, here shaped by pattern, proximity, and gesture.
The result is intimate and modern: a private routine made monumental by close observation."""
    ),
    (
        "Boulevard Montmartre, Spring",
        "general public",
        """Camille Pissarro painted a series of views of the Boulevard Montmartre in 1897, recording the Paris thoroughfare in different seasons and weathers.
In this spring version, fresh light scatters across carriages, trees, and pedestrians.
Pissarro built the scene with small, varied strokes that keep the surface lively, allowing atmosphere to mingle with architecture.
From a high window, he looks down the boulevard’s long diagonal, a vantage that turns the city into a pattern of motion.
As an elder Impressionist, Pissarro remained committed to painting from direct observation, treating the modern street as a landscape of human activity.
The picture is both factual and lyrical, inviting viewers to sense the changing air as much as the measured facades."""
    ),
    (
        "Paris Street; Rainy Day",
        "general public",
        """Gustave Caillebotte’s Paris Street; Rainy Day (1877) presents the new boulevards of Haussmann’s Paris under a pale, wet sky.
Umbrellas tilt at different angles as pedestrians pass with measured steps, their reflections pooling on the cobbles.
Caillebotte combines photographic precision with a modern sense of space—broad avenues, cut corners, and unexpected crops.
Cool grays and blues unify the scene; touches of brown and rose warm the figures without romanticizing them.
Though often grouped with the Impressionists, Caillebotte painted with a tighter surface, yet shared their interest in contemporary urban life.
The painting conveys a quiet drama of coordination—each person absorbed in purpose, yet part of a shared rhythm shaped by weather and city design."""
    ),
    (
        "The Bridge at Villeneuve-la-Garenne",
        "general public",
        """Alfred Sisley’s The Bridge at Villeneuve-la-Garenne (1872) studies light playing across water and iron.
Crisp shadows from the bridge’s trusses stripe the river, while small boats and distant banks anchor the view.
Sisley favored calm atmospheres and subtle color, letting blues and greens shift gently rather than collide.
His even touch and attention to reflections turn a modern structure into a subject of quiet beauty.
The painting exemplifies core Impressionist concerns: painting outdoors, capturing transient conditions, and treating contemporary motifs with freshness rather than monumentality."""
    ),
    (
        "Haystacks (Grainstacks), End of Summer",
        "general public",
        """Claude Monet’s haystack series (1890–91) explores how one motif changes with season, weather, and time of day.
In End of Summer, warm light suffuses the stacks and field, while violet shadows give form without hard edges.
Monet worked in pairs of canvases to follow shifting conditions, returning at set hours to keep each picture consistent.
Color carries structure: oranges and golds glow against complementary blues and purples.
Rather than illustrate agriculture, the series becomes a meditation on perception—how the same object is never seen the same way twice.
What we recognize as “haystacks” is built from harmonized touches of color that cohere at a distance and dissolve up close."""
    ),
    (
        "Rouen Cathedral, West Façade, Sunlight",
        "general public",
        """Monet’s Rouen Cathedral series treats stone as if it were a screen for light.
In the Sunlight version (1894), the façade flickers between solidity and radiance as morning color warms the tracery.
Paint is laid on in short, layered strokes that catch and scatter illumination like facets.
Monet painted from a rented room across the square, working on multiple canvases as the light changed.
Rather than a portrait of architecture alone, the series studies how time, weather, and atmosphere alter perception.
The cathedral remains constant; our experience of it does not. Monet turns a Gothic monument into a record of the passing day."""
    ),
    (
        "L’Absinthe",
        "general public",
        """Degas’s L’Absinthe (1875–76) shows two figures seated at a café table, their gazes unfocused, their bodies slumped.
Diagonal cropping and empty space heighten the feeling of isolation despite physical proximity.
The picture was controversial for its frankness, not for moralizing; Degas observes rather than instructs.
Muted ochers, grays, and greens evoke smoke and stale air, while small accents—the glass, the carafe—punctuate the scene.
Like many Impressionists, Degas examined modern life with an unsentimental eye, finding drama in ordinary settings.
Here, urban leisure feels heavy rather than sparkling, a counterpoint to images of dance and theater.
The work invites reflection on how public places can sharpen loneliness as easily as sociability."""
    ),
    (
        "Family Reunion",
        "general public",
        """Frédéric Bazille’s Family Reunion (1867) gathers relatives in a garden near Montpellier.
Painted before the firs  Impressionist exhibition, it anticipates the group’s outdoor light and informal arrangement.
Figures are integrated into the landscape rather than staged in studio grandeur; faces and clothing are observed with sympathetic clarity.
Bazille, a close friend of Monet and Renoir, died young in the Franco-Prussian War, but his canvases helped set a direction for modern painting:
scenes of contemporary life in natural light, handled with broad color and a sense of immediacy.
The painting holds poise between portrait and genre, making family presence itself the subject."""
    ),
]

# %%
from langsmith import Client

client = Client()

dataset_name = "museum-generator-golden-dataset"
description = (
    "Golden set for the Museum Description Generator — "
    "canonical artworks with reference labels written for a general audience."
)

# Create the dataset
try:
    dataset = client.read_dataset(dataset_name=dataset_name)
except Exception:
    dataset = client.create_dataset(dataset_name=dataset_name, description=description)

inputs = [{"artwork": a, "audience": aud} for (a, aud, _) in GOLDEN_EXAMPLES]
outputs = [{"output": label} for (_, _, label) in GOLDEN_EXAMPLES]

client.create_examples(inputs=inputs, outputs=outputs, dataset_id=dataset.id)

print(f"Dataset ready: {dataset_name} (id={dataset.id})")
# Out:
# Dataset ready: museum-generator-golden-dataset (id=034172e3-50ef-40af-ad85-10cde777fca0)

# %% [markdown]
# ### Back to UI: Create auto-evaluators on the UI or through code

# %%
def is_concise_enough(reference_outputs: dict, outputs: dict) -> dict:
    score = len(outputs["output"]) < 1.5 * len(reference_outputs["output"])
    return {"key": "is_concise", "score": int(score)}

def no_beautiful_or_amazing(reference_outputs: dict, outputs: dict) -> dict:
    words = outputs["output"].split(" ")
    score = 1
    if "beautiful" in words or "amazing" in words:
        score = 0
    return {"key": "no_beautiful_or_amazing", "score": score}

# %% [markdown]
# ### Run Experiment:

# %%
from langsmith import evaluate, Client

client = Client()
dataset_name = "museum-generator-golden-dataset"

#build target function
client = Client()  # uses LANGSMITH_API_KEY from env
# PROMPT = client.pull_prompt("target-audience-prompt:b07b0a6b", include_model=True)
PROMPT = client.pull_prompt("artwork-only-prompt:5faa46b1", include_model=True)

@traceable(run_type="chain", name=f"museum_label (prompt=target-audience-prompt:b07b0a6b)")
def target_function(inputs: dict):
    artwork  = inputs.get("artwork") 
    audience = inputs.get("audience")
    prompt = PROMPT
    output = museum_caption_generator(artwork, audience, prompt)
    return { "output": output}



evaluate(
    target_function,
    data=dataset_name,
    evaluators=[is_concise_enough, no_beautiful_or_amazing],
    experiment_prefix="audience-focused-prompt"
)
# Out:
# View the evaluation results for experiment: 'audience-focused-prompt-bea6d2cf' at:
# https://smith.langchain.com/o/dafd6f38-c588-41d5-8359-e7f75b38037d/datasets/034172e3-50ef-40af-ad85-10cde777fca0/compare?selectedSessions=3285880c-34b0-413b-a875-619d9688454f
# 82it [19:39, 14.39s/it]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/utils.py:159, in raise_for_status_with_text(response)
#     158 try:
# --> 159     response.raise_for_status()
#     160 except requests.HTTPError as e:
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.smith.langchain.com/sessions/3285880c-34b0-413b-a875-619d9688454f
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/client.py:937, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     931     response = self.session.request(
#     932         method,
#     933         _construct_url(self.api_url, pathname),
#     934         stream=False,
#     935         **request_kwargs,
#     936     )
# --> 937 ls_utils.raise_for_status_with_text(response)
#     938 return response
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/utils.py:161, in raise_for_status_with_text(response)
#     160 except requests.HTTPError as e:
# --> 161     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     162 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 404 Client Error: Not Found for url: https://api.smith.langchain.com/sessions/3285880c-34b0-413b-a875-619d9688454f] {"detail":"Project not found."}
#
# During handling of the above exception, another exception occurred:
#
# LangSmithNotFoundError                    Traceback (most recent call last)
# Cell In[86], line 21
#      16     output = museum_caption_generator(artwork, audience, prompt)
#      17     return { "output": output}
# ---> 21 evaluate(
#      22     target_function,
#      23     data=dataset_name,
#      24     evaluators=[is_concise_enough, no_beautiful_or_amazing],
#      25     experiment_prefix="audience-focused-prompt"
#      26 )
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:423, in evaluate(target, data, evaluators, summary_evaluators, metadata, experiment_prefix, description, max_concurrency, num_repetitions, client, blocking, experiment, upload_results, error_handling, **kwargs)
#     421     _warn_once("'upload_results' parameter is in beta.")
#     422 logger.debug(f"Running evaluation over target system {target}...")
# --> 423 return _evaluate(
#     424     target,
#     425     data=data,
#     426     evaluators=cast(Optional[Sequence[EVALUATOR_T]], evaluators),
#     427     summary_evaluators=summary_evaluators,
#     428     metadata=metadata,
#     429     experiment_prefix=experiment_prefix,
#     430     description=description,
#     431     max_concurrency=max_concurrency,
#     432     num_repetitions=num_repetitions,
#     433     client=client,
#     434     blocking=blocking,
#     435     experiment=experiment,
#     436     upload_results=upload_results,
#     437     error_handling=error_handling,
#     438 )
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1101, in _evaluate(target, data, evaluators, summary_evaluators, metadata, experiment_prefix, description, max_concurrency, num_repetitions, client, blocking, experiment, upload_results, error_handling)
#    1099     manager = manager.with_summary_evaluators(summary_evaluators)
#    1100 # Start consuming the results.
# -> 1101 results = ExperimentResults(manager, blocking=blocking)
#    1102 return results
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:580, in ExperimentResults.__init__(self, experiment_manager, blocking)
#     578 else:
#     579     self._thread = None
# --> 580     self._process_data()
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:605, in ExperimentResults._process_data(self)
#     603 tqdm = _load_tqdm()
#     604 results = self._manager.get_results()
# --> 605 for item in tqdm(results):
#     606     self._queue.put(item)
#     607     self._results.append(item)
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1521, in _ExperimentManager.get_results(self)
#    1519 def get_results(self) -> Iterable[ExperimentResultRow]:
#    1520     """Return the traces, evaluation results, and associated examples."""
# -> 1521     for run, example, evaluation_results in zip(
#    1522         self.runs, self.examples, self.evaluation_results
#    1523     ):
#    1524         yield ExperimentResultRow(
#    1525             run=run,
#    1526             example=example,
#    1527             evaluation_results=evaluation_results,
#    1528         )
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1501, in <genexpr>(.0)
#    1496 # Split the generator into three so the manager
#    1497 # can consume each value individually.
#    1498 r1, r2, r3 = itertools.tee(experiment_results, 3)
#    1499 return self._copy(
#    1500     (result["example"] for result in r1),
# -> 1501     runs=(result["run"] for result in r2),
#    1502     evaluation_results=(result["evaluation_results"] for result in r3),
#    1503 )
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1690, in _ExperimentManager._score(self, evaluators, max_concurrency)
#    1688 if max_concurrency == 0:
#    1689     context = copy_context()
# -> 1690     for current_results in self.get_results():
#    1691         yield context.run(
#    1692             self._run_evaluators,
#    1693             evaluators,
#    1694             current_results,
#    1695             executor,
#    1696         )
#    1697 else:
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1521, in _ExperimentManager.get_results(self)
#    1519 def get_results(self) -> Iterable[ExperimentResultRow]:
#    1520     """Return the traces, evaluation results, and associated examples."""
# -> 1521     for run, example, evaluation_results in zip(
#    1522         self.runs, self.examples, self.evaluation_results
#    1523     ):
#    1524         yield ExperimentResultRow(
#    1525             run=run,
#    1526             example=example,
#    1527             evaluation_results=evaluation_results,
#    1528         )
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1476, in <genexpr>(.0)
#    1468 _experiment_results = context.run(
#    1469     self._predict,
#    1470     target,
#    1471     max_concurrency=max_concurrency,
#    1472     include_attachments=_target_include_attachments(target),
#    1473 )
#    1474 r1, r2 = itertools.tee(_experiment_results, 2)
#    1475 return self._copy(
# -> 1476     (pred["example"] for pred in r1), runs=(pred["run"] for pred in r2)
#    1477 )
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1587, in _ExperimentManager._predict(self, target, max_concurrency, include_attachments)
#    1585             yield future.result()
#    1586 # Close out the project.
# -> 1587 self._end()
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/evaluation/_runner.py:1809, in _ExperimentManager._end(self)
#    1807 project_metadata["dataset_version"] = self._get_dataset_version()
#    1808 project_metadata["dataset_splits"] = self._get_dataset_splits()
# -> 1809 self.client.update_project(
#    1810     experiment.id,
#    1811     metadata={
#    1812         **experiment.metadata,
#    1813         **project_metadata,
#    1814     },
#    1815 )
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/client.py:3440, in Client.update_project(self, project_id, name, description, metadata, project_extra, end_time)
#    3433     extra = {**(extra or {}), "metadata": metadata}
#    3434 body: dict[str, Any] = {
#    3435     "name": name,
#    3436     "extra": extra,
#    3437     "description": description,
#    3438     "end_time": end_time.isoformat() if end_time else None,
#    3439 }
# -> 3440 response = self.request_with_retries(
#    3441     "PATCH",
#    3442     endpoint,
#    3443     headers={**self._headers, "Content-Type": "application/json"},
#    3444     data=_dumps_json(body),
#    3445 )
#    3446 ls_utils.raise_for_status_with_text(response)
#    3447 return ls_schemas.TracerSession(**response.json(), _host_url=self._host_url)
#
# File ~/intro-to-langsmith/ls-academy/lib/python3.12/site-packages/langsmith/client.py:977, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     972     raise ls_utils.LangSmithAuthError(
#     973         f"Authentication failed for {pathname}. {repr(e)}"
#     974         f"{_context}"
#     975     )
#     976 elif response.status_code == 404:
# --> 977     raise ls_utils.LangSmithNotFoundError(
#     978         f"Resource not found for {pathname}. {repr(e)}"
#     979         f"{_context}"
#     980     )
#     981 elif response.status_code == 409:
#     982     raise ls_utils.LangSmithConflictError(
#     983         f"Conflict for {pathname}. {repr(e)}{_context}"
#     984     )
#
# LangSmithNotFoundError: Resource not found for https://api.smith.langchain.com/sessions/3285880c-34b0-413b-a875-619d9688454f. HTTPError('404 Client Error: Not Found for url: https://api.smith.langchain.com/sessions/3285880c-34b0-413b-a875-619d9688454f', '{"detail":"Project not found."}')

# %% [markdown]
# ### Pairwise evaluations:

# %% [markdown]
# ### Annotation Queues

# %% [markdown]
# ## 4) Monitoring & Improvements: online evals, automations, and dashboards.

# %% [markdown]
# ## 6) Wrap-up
# - Tracing with `@traceable` + LangGraph, metadata & filtering.
# - Golden datasets, rule evaluators, LLM-as-judge scaffold, dataset splits.
# - Prod monitoring ideas and automation chaining via webhooks.
